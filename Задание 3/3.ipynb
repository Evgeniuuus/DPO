# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Задание 3/Погибло_лесных_насаждений.xlsx', header=0)
print("\n")
df.info()
print("\n")
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Задание 3/out_put.csv', header= True)
df.describe(include= 'all')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 9 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Unnamed: 0                                        94 non-null     object
#  1   Unnamed: 1                                        94 non-null     float64
#  2   24210000100290200001 Погибло лесных насаждений    86 non-null     object
#  3   24210000100290200001 Погибло лесных насаждений.1  88 non-null     object
#  4   24210000100290200001 Погибло лесных насаждений.2  84 non-null     object
#  5   24210000100290200001 Погибло лесных насаждений.3  87 non-null     object
#  6   24210000100290200001 Погибло лесных насаждений.4  88 non-null     object
# ...

# %%
import sqlite3

conn = sqlite3.connect('/content/drive/MyDrive/Colab Notebooks/Задание 3/films.db')
query = """SELECT * FROM films"""
df = pd.read_sql(query, conn)
conn.close()
df.info()
print("\n")
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Задание 3/out_put_sql.csv', header= True)
df.describe(include= 'all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17184 entries, 0 to 17183
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        17184 non-null  int64
#  1   title     17184 non-null  object
#  2   year      17184 non-null  int64
#  3   genre     17184 non-null  int64
#  4   duration  17184 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 671.4+ KB
#                   id          title          year         genre      duration
# count   17184.000000          17184  17184.000000  17184.000000  17184.000000
# unique           NaN          16041           NaN           NaN           NaN
# top              NaN  Анна Каренина           NaN           NaN           NaN
# freq             NaN              7           NaN           NaN           NaN
# mean     8902.078270            NaN   1988.023277      5.574081    111.131983
# ...
