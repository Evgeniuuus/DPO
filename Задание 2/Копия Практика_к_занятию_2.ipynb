# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# пусть даны строки
raw1 = ['Иванов Иван Иванович', 41, 'Водитель']
raw2 = ['Петров Петр Петрович', 52, 'Менеджер']
raw3 = ['Сидорова Валентина Витальевна', 30, 'Специалист по недвижимости']
# заголовки таблицы
columns = ['Ф.И.О.', 'Возраст', 'Должность']

df = pd.DataFrame(data = [raw1, raw2, raw3], columns=columns)

df
# Out:
#                           Ф.И.О.  Возраст                   Должность
# 0           Иванов Иван Иванович       41                    Водитель
# 1           Петров Петр Петрович       52                    Менеджер
# 2  Сидорова Валентина Витальевна       30  Специалист по недвижимости

# %%
oscar_age_female = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/oscar_age_female.csv")
oscar_age_female.head()
# Out:
#    Index   "Year"              "Age"                           "Name"  \
# 1   1928       22     "Janet Gaynor"                  "Seventh Heaven
# 2   1929       37    "Mary Pickford"                       "Coquette"
# 3   1930       28    "Norma Shearer"                 "The Divorcee"\t
# 4   1931       63   "Marie Dressler"                   "Min and Bill"
# 5   1932       32      "Helen Hayes"   "The Sin of Madelon Claudet"\t
#
#                                             "Movie"
# 1   Street Angel and Sunrise: A Song of Two Humans"
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN

# %%
oscar_age_female = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/oscar_age_female.csv",
                               names=['Index', 'Year', 'Age', 'Name', 'Movie', 'Movie2'], header = 0)
oscar_age_female.head()

oscar_age_female.columns
# Out:
# Index(['Index', 'Year', 'Age', 'Name', 'Movie', 'Movie2'], dtype='object')

# %%
oscar_age_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Index   89 non-null     int64
#  1   Year    89 non-null     int64
#  2   Age     89 non-null     int64
#  3   Name    89 non-null     object
#  4   Movie   89 non-null     object
#  5   Movie2  2 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 4.3+ KB

# %% [markdown]
#  89 записей, от 0 до 88 </br>
#  тип данных int(64) - целые</br>
#  not-null говорит нам о том что не пустые значения</br>

# %%
oscar_age_female.describe(include= 'all')
# Out:
#             Index         Year        Age                  Name  \
# count   89.000000    89.000000  89.000000                    89
# unique        NaN          NaN        NaN                    74
# top           NaN          NaN        NaN   "Katharine Hepburn"
# freq          NaN          NaN        NaN                     4
# mean    45.000000  1972.000000  36.123596                   NaN
# std     25.836021    25.836021  11.745231                   NaN
# min      1.000000  1928.000000  21.000000                   NaN
# 25%     23.000000  1950.000000  28.000000                   NaN
# 50%     45.000000  1972.000000  33.000000                   NaN
# 75%     67.000000  1994.000000  41.000000                   NaN
# max     89.000000  2016.000000  80.000000                   NaN
#
#                    Movie                                            Movie2
# count                 89                                                 2
# ...

# %% [markdown]
#  - 89
#  - нет
#  - не на много
#  - не имеется
#  - 45 два раза

# %%
nans = pd.DataFrame(data = oscar_age_female.isna().sum(), columns = ['NaN_count'])
nans
# Out:
#         NaN_count
# Index           0
# Year            0
# Age             0
# Name            0
# Movie           0
# Movie2         87

# %%
oscar_age_female['Movie2'].fillna('-', inplace = False)
oscar_age_female
# Out:
#     Index  Year  Age                  Name                            Movie  \
# 0       1  1928   22        "Janet Gaynor"                  "Seventh Heaven
# 1       2  1929   37       "Mary Pickford"                       "Coquette"
# 2       3  1930   28       "Norma Shearer"                 "The Divorcee"\t
# 3       4  1931   63      "Marie Dressler"                   "Min and Bill"
# 4       5  1932   32         "Helen Hayes"   "The Sin of Madelon Claudet"\t
# ..    ...   ...  ...                   ...                              ...
# 84     85  2012   62        "Meryl Streep"                  "The Iron Lady"
# 85     86  2013   22   "Jennifer Lawrence"        "Silver Linings Playbook"
# 86     87  2014   44      "Cate Blanchett"                   "Blue Jasmine"
# 87     88  2015   54      "Julianne Moore"                    "Still Alice"
# 88     89  2016   26         "Brie Larson"                           "Room"
#
#                                               Movie2
# ...

# %%
df_without_na = oscar_age_female.dropna()
df_without_na.shape
# Out:
# (2, 6)

# %% [markdown]
# Было 89 - стало 2

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
x = oscar_age_female['Year']
y = oscar_age_female['Age']
plt.scatter(x,y)
plt.xlabel('Year')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# В основном молодые получают оскара

# %%
titanic = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
titanic = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/titanic.csv",
                      names=['PassengerId','Pclass', 'Name', 'Sex', 'Age',
                             'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin',
                             'Embarked','Survived'], header = 0)
titanic.head()

titanic.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    object
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Survived     891 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
#  891 записей, от 0 до 890 </br>
#  тип данных int(64) и float(64) - целые и дробные</br>
#  not-null говорит нам о том что не пустые значения</br>

# %%
titanic.describe(include= 'all')
# Out:
#         PassengerId      Pclass                     Name   Sex         Age  \
# count    891.000000  891.000000                      891   891  714.000000
# unique          NaN         NaN                      891     2         NaN
# top             NaN         NaN  Braund, Mr. Owen Harris  male         NaN
# freq            NaN         NaN                        1   577         NaN
# mean     446.000000    2.308642                      NaN   NaN   29.699118
# std      257.353842    0.836071                      NaN   NaN   14.526497
# min        1.000000    1.000000                      NaN   NaN    0.420000
# 25%      223.500000    2.000000                      NaN   NaN   20.125000
# 50%      446.000000    3.000000                      NaN   NaN   28.000000
# 75%      668.500000    3.000000                      NaN   NaN   38.000000
# max      891.000000    3.000000                      NaN   NaN   80.000000
#
# ...

# %% [markdown]
#  - 891
#  - есть
#  - на много
#  - имеется
#  - 456 два раза

# %%
nans = pd.DataFrame(data = titanic.isna().sum(), columns = ['NaN_count'])
nans
# Out:
#              NaN_count
# PassengerId          0
# Pclass               0
# Name                 0
# Sex                  0
# Age                177
# SibSp                0
# Parch                0
# Ticket               0
# Fare                 0
# Cabin              687
# Embarked             2
# Survived             0

# %%
titanic['Cabin'].fillna('-', inplace = False)
titanic
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df_without_na = titanic.dropna()
df_without_na.shape
# Out:
# (183, 12)

# %% [markdown]
# Было 891 - стало 183

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
x = titanic['PassengerId']
y = titanic['Fare']
plt.scatter(x,y)
plt.xlabel('people')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# В среднем 25 рублей за проезд
