# %% [markdown]
# # Упражнения на работу с датафреймами

# %% [markdown]
# ## Инструкция по выполнению задания
#
# Ниже находится несколько  упражнений, представляющих собой код с пропущенными фрагментами, которые надо восстановить. Часть из этих упражнений очень простые, над некоторыми надо хорошенько подумать.
#
# Чтобы выполнить это задание, нужно сохранить копию файла `*.ipynb` себе на Google-диск. После выполнения задания, его нужно отправить на проверку. Для этого достаточно предоставить доступ к файлу и отправить ссылку в соответствующее поле LMS курса.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Импортируем библиотеку pandas
# И numpy заодно.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 1
# Сделайте датафрейм из представленных ниже списков.

# %%
# пусть даны строки
raw1 = ['Иванов Иван Иванович', 41, 'Водитель']
raw2 = ['Петров Петр Петрович', 52, 'Менеджер']
raw3 = ['Сидорова Валентина Витальевна', 30, 'Специалист по недвижимости']
# заголовки таблицы
columns = ['Ф.И.О.', 'Возраст', 'Должность']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 2
# С помощью метода read_csv() загрузите датафрейм из файла `oscar_age_female.csv` (предварительно скопируйте файл на свой Google-диск и подключите его). Файл содержит информацию о женщинах, получивших премию Оскар. С помощью метода `head()` выведите начало таблицы на экран.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 3
# Оскар у некоторых актрис был присужден сразу за несколько фильмов. Из-за этого заголовки таблицы и ее содержимое при создании датафрейма немного не совпадают. Добавьте столбец 'Movie2', чтобы датафрейм отображался корректно.
# Для того, чтобы это сделать вам может понадобиться справочная информация по методу  [read_csv()](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html). Также выведите список названий столбцов.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 4
# Выведите на экран информацию о наборе данных (используя метод `info()`), Опишите датасет: размеры, типы данных, имеются ли пропуски.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 5
#
# Выведите на экран описательные характеристики признаков (используя метод `describe()`). Какие статистические показатели вы увидели в данных? Запишите:
# - каков размах значений у числовых признаков;
# - есть ли отклонения медианы от среднего в числовых признаках;
# - насколько сильно разбросаны значения вокруг среднего;
# - имеется / не имеется мода в категориальных признаках;
# - какое значение является модальным, сколько раз оно встречается.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 6
#
# Посмотрите, есть ли в датасете незаполненные значения (*nan*'ы) с помощью метода `isna()`. Постройте табличку с количеством *nan* в каждой колонке.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 7
#
# Если пропуски имеются, замените их на что-нибудь подходящее с помощью метода `fillna()` (например, столбец 'Movie2' заполнить прочерками вместо 'Nan')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Примечание
#
# Строки с пропусками (или столбцы) можно удалить (метод `dropna()`). Но это может очень сильно повлиять на размер итогового датафрейма! Выполните данный код и узнайте, сколько строк осталось в результате:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 8
#
# Постройте диаграмму по двум числовым признакам (например, `'Year'` и `'Age'`). Перед этим импортируйте бибилотеку `matplotlib` для работы с графиками.
#
# Дайте свою интерпретацию тому, что увидели на диаграмме.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Упражнение 9
#
# Самостоятельно проделайте аналогичные операции с другим набором данных (файл `titanic.csv`)
